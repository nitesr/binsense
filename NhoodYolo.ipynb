# %% [markdown]
# <a href="https://colab.research.google.com/github/nitesr/binsense/blob/main/NhoodYolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
ROOT_DIR = '/content/drive/MyDrive/data'


# !pip install ultralytics

# %%
import os

from ultralytics import YOLO


# Load a model
#model = YOLO("yolov8n.yaml")  # build a new model from scratch

# Use the model
#results = model.train(data=os.path.join(ROOT_DIR, "data.yaml"), epochs=100)  # train the model
# !yolo task=detect mode=train model=yolov8s.pt data= /content/drive/MyDrive/data/data.yaml epochs=100 plots=True
# Out:
# Ultralytics YOLOv8.1.47 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=val model=/content/drive/MyDrive/data/runs/detect/train21/weights/best.pt data= /content/drive/MyDrive/data/data.yaml
# Out:
# Ultralytics YOLOv8.1.47 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11148417 parameters, 0 gradients, 28.6 GFLOPs
# val: Scanning /content/drive/MyDrive/data/yolo/labels/val.cache... 15 images, 0 backgrounds, 0 corrupt: 100% 15/15 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:03<00:00,  3.83s/it]
#                    all         15         28    0.00397     0.0556      0.023      0.013
#             B00IOSJ72M         15          2          0          0          0          0
#             B01954LZV4         15          2          0          0          0          0
#             B014KOHYRS         15          1          0          0          0          0
#             B00B7LQ9QU         15          1          0          0          0          0
#             B00SBXIN0M         15          1          0          0          0          0
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/data/runs/detect/train21/weights/best.pt conf=0.25 source=/content/drive/MyDrive/data/yolo/images/test/
# Out:
# Ultralytics YOLOv8.1.47 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11148417 parameters, 0 gradients, 28.6 GFLOPs
#
# image 1/15 /content/drive/MyDrive/data/yolo/images/test/117124.jpg: 512x640 1 B00475VF9E, 72.9ms
# image 2/15 /content/drive/MyDrive/data/yolo/images/test/117125.jpg: 512x640 (no detections), 13.4ms
# image 3/15 /content/drive/MyDrive/data/yolo/images/test/141823.jpg: 608x640 1 B000EVPGSQ, 1 B00I2F3EBM, 74.4ms
# image 4/15 /content/drive/MyDrive/data/yolo/images/test/141824.jpg: 640x512 1 B00JSRML62, 68.1ms
# image 5/15 /content/drive/MyDrive/data/yolo/images/test/141829.jpg: 480x640 1 B00CA6756O, 70.6ms
# image 6/15 /content/drive/MyDrive/data/yolo/images/test/14183.jpg: 512x640 1 B00KCUU52Q, 1 B00475VF9E, 14.1ms
# image 7/15 /content/drive/MyDrive/data/yolo/images/test/141830.jpg: 640x448 1 B01DTEXPWS, 80.2ms
# image 8/15 /content/drive/MyDrive/data/yolo/images/test/141831.jpg: 640x448 1 B00BSJY61Q, 12.0ms
# ...

# %%
# !scp -r /content/runs '/content/drive/MyDrive/data/'

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob('/content/drive/MyDrive/data/runs/detect/predict/*.jpg')[:3]:
      display(Image(filename=image_path, width=600))
      print("\n")
